# %% [markdown]
# ## How do we convert our audio files to image files?

# %% [markdown]
# We should now have some augmented audio files in `/workspace/data/augmented_audio`, but our model training notebooks work with images. This notebook will create these audio files for us and place them in a folder named `lakota_data`.
#
# The cell below provide the tools to create the necessary images. `Librosa` is a popular library for carrying out this task.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import os

# %% [markdown]
# The function below `audio_to_melspectrogram_image()` is the function that will create the images for us, and we have some options that you may want to modify that will influence the image that gets produced.
#
# In particular, the parameter called `cmap` in the line
# `librosa.display.specshow(mel_db, sr=sr, fmax=fmax, cmap='viridis')`.
# The `cmap` parameter controls the color map of the images and an explanation of the options is below.
#
# The default option selected is `cmap='viridis'`, but you can use any of the options below to create different spectrograms for your model training.
#
# 🔵 Perceptually Uniform Colormaps (Good for ML and clarity)
#  - 'viridis' – (default you’re using) good contrast, colorblind-friendly.
#  - 'plasma' – vibrant and high-contrast.
#  - 'inferno' – dark background, high dynamic range.
#  - 'magma' – smoother than inferno, darker background.
#  - 'cividis' – designed for color vision deficiency.
#
# 🌈 Traditional/Classic Colormaps
#  - 'jet' – very colorful, but not perceptually uniform (can mislead perception).
#  - 'hot' – black to red to yellow to white.
#  - 'cool' – cyan to magenta gradient.
#  - 'spring', 'summer', 'autumn', 'winter' – seasonal gradient palettes.
#
# ⚫ Grayscale and Inverted
#  - 'gray' – grayscale (black = low, white = high).
#  - 'bone', 'binary', 'gist_yarg' – variations of grayscale.
#  - 'Greys', 'Purples', 'Blues', 'Oranges', 'Reds' – monochrome ramps.
#  - 'copper', 'pink', 'coolwarm' – alternative tones with visual flair.
#
# 🔁 Inverted Colormaps
#
# You can invert any colormap by appending `_r`, e.g.:
#  - 'viridis_r'
#  - 'inferno_r'
#  - 'gray_r'

# %%
def audio_to_melspectrogram_image(audio_path, output_path, sr=16000, n_mels=128, fmax=8000):
    y, sr = librosa.load(audio_path, sr=sr)
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, fmax=fmax)
    mel_db = librosa.power_to_db(mel, ref=np.max)

    plt.figure(figsize=(2.24, 2.24))  # For 224x224 px output
    librosa.display.specshow(mel_db, sr=sr, fmax=fmax, cmap='viridis')
    plt.axis('off')
    plt.tight_layout()
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0)
    plt.close()
    print(f"Saved: {output_path}")

# %% [markdown]
# The cell below will take our augmented audio files and produce all of the images that we will need for training.

# %%
input_dir = "/workspace/data/augmented_audio"
output_dir = "/workspace/data/lakota_data"
os.makedirs(output_dir, exist_ok=True)

input_root = Path(input_dir)
input_files = list(input_root.rglob("*.wav"))
print(f"Found {len(input_files)} audio files in {input_dir}")

for root, _, files in os.walk(input_dir):
    for fname in files:
        if fname.endswith(".wav"):
            rel_path = os.path.relpath(root, input_dir)  # e.g., 'red' or 'yellow'
            input_path = os.path.join(root, fname)

            # Construct output path with same subdir structure
            target_dir = os.path.join(output_dir, rel_path)
            os.makedirs(target_dir, exist_ok=True)

            output_path = os.path.join(target_dir, fname.replace(".wav", ".png"))
            audio_to_melspectrogram_image(input_path, output_path)
            
print(f"\n✅ Done. Augmented files saved to: {output_dir}")
# Out:
# Found 786 audio files in /workspace/data/augmented_audio
# Saved: /workspace/data/lakota_data/napciyunka_nine/napciyunka
# Saved: /workspace/data/lakota_data/sa/sa_red (23)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (23)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (23)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (24)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (24)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (24)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (25)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (25)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (25)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (26)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (26)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (26)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (27)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (27)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (27)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (28)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (28)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (28)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (29)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (29)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (29)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (30)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (30)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (30)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (31)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (31)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (31)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (32)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (32)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (32)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (33)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (33)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (33)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (34)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (34)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (34)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (35)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (35)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (35)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (36)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (36)_aug2.png
# Saved: /workspace/data/lakota_data/sa/sa_red (36)_aug3.png
# Saved: /workspace/data/lakota_data/sa/sa_red (37)_aug1.png
# Saved: /workspace/data/lakota_data/sa/sa_red (37)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (17)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (17)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (17)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (18)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (18)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (18)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (19)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (19)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (19)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (2)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (2)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (2)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (3)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (3)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (3)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (4)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (4)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (4)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (5)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (5)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (5)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (6)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (6)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (6)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (7)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (7)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (7)_aug3.png
# Saved: /workspace/data/lakota_data/takuni/takuni (9)_aug1.png
# Saved: /workspace/data/lakota_data/takuni/takuni (9)_aug2.png
# Saved: /workspace/data/lakota_data/takuni/takuni (9)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (1)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (1)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (1)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (10)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (10)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (10)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (11)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (11)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (11)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (12)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (12)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (12)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (13)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (13)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (13)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (14)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (14)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (14)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (15)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (15)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (15)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (16)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (16)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (16)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (17)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (17)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (17)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (18)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (18)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (18)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (19)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (19)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (19)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (2)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (2)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (2)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (20)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (20)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (20)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (3)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (3)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (3)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (4)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (4)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (4)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (5)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (5)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (5)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (6)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (6)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (6)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (7)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (7)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (7)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (8)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (8)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (8)_aug3.png
# Saved: /workspace/data/lakota_data/topa/topa (9)_aug1.png
# Saved: /workspace/data/lakota_data/topa/topa (9)_aug2.png
# Saved: /workspace/data/lakota_data/topa/topa (9)_aug3.png
# Saved: /workspace/data/lakota_data/wanzi/wanzi (1)_aug1.png
# Saved: /workspace/data/lakota_data/wanzi/wanzi (1)_aug2.png
# Saved: /workspace/data/lakota_data/wanzi/wanzi
# Saved: /workspace/data/lakota_data/yamni/yamni (12)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (13)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (13)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (13)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (14)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (14)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (14)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (15)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (15)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (15)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (16)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (16)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (16)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (17)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (17)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (17)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (18)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (18)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (18)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (19)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (19)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (19)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (2)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (2)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (2)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (20)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (20)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (20)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (3)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (3)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (3)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (4)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (4)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (4)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (5)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (5)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (5)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (6)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (6)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (6)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (7)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (7)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (7)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (8)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (8)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (8)_aug3.png
# Saved: /workspace/data/lakota_data/yamni/yamni (9)_aug1.png
# Saved: /workspace/data/lakota_data/yamni/yamni (9)_aug2.png
# Saved: /workspace/data/lakota_data/yamni/yamni (9)_aug3.png
# Saved: /workspace/data/lakota_data/zaptan/zaptan